# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

user = "Sh1v02"
repo = "Traffic-Flow-Road-Incident"
branch = "GPU_Support"

#this is my token but go ahead and use it
#or generate your own (developer settings on GitHub)
token = "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"

# remove local directory if it already exists
if os.path.isdir(repo):
    # !rm -rf {repo}

url = f"https://{token}@github.com/{user}/{repo}.git"
! git clone -b {branch} $url

# %%
# !pip install -r Traffic-Flow-Road-Incident/requirements_colab.txt

# %% [markdown]
# # Single Agent Run

# %%
# !python Traffic-Flow-Road-Incident/colab_run_single_agent.py

# %% [markdown]
# # Multi Agent Run

# %%
# !python Traffic-Flow-Road-Incident/colab_run_multi_agent.py
